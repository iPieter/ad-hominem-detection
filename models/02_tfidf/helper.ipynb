# %%
from nltk.util import skipgrams
import pandas as pd

# %%
def get_data():
    return pd.read_csv('../../data/merged_datasets.csv', usecols=(['body', 'isAdHominem']))

# %%
def get_data_with_skip_n_grams(n, k):
    data = get_data()
    for index, row in data.iterrows():
        data.at[index, 'body'] = list(skipgrams(data.loc[index, 'body'].split(), n, k))
    return data

# %%
get_data_with_skip_n_grams(3,3)
# Out:
#                                                     body  isAdHominem
# 0      [(What, makes, corporations), (What, makes, di...        False
# 1      [(>there, are, arguments), (>there, are, that)...         True
# 2      [(Basically, to, believe), (Basically, to, a),...        False
# 3      [(The, punishment, for), (The, punishment, her...        False
# 4      [(No, it, doesn't.), (No, it, Sex), (No, it, i...        False
# 5      [(I, know, I), (I, know, shouldn't), (I, know,...        False
# 6      [(You, weren't, at), (You, weren't, a), (You, ...        False
# 7      [(>, My, point), (>, My, was), (>, My, that), ...        False
# 8      [(Fuck, Trump,, there), (Fuck, Trump,, is), (F...        False
# 9      [(I, have, an), (I, have, extremely), (I, have...        False
# 10     [(I, am, a), (I, am, 16), (I, am, year), (I, a...        False
# 11     [(>Are, you, taking), (>Are, you, umbrage), (>...        False
# 12     [(Alright,, I'm, just), (Alright,, I'm, going)...        False
# 13     [(Today, I, was), (Today, I, asked), (Today, I...        False
# 14     [(It, wasn't, an), (It, wasn't, argument,), (I...        False
# 15     [(>misconceptions, of, studies), (>misconcepti...        False
# 16     [(In, Switzerland,, school), (In, Switzerland,...        False
# 17     [(Guns, are, used), (Guns, are, safely), (Guns...        False
# 18     [(What, about, Yongzheng), (What, about, emanc...        False
# 19     [(No, you, hate), (No, you, liberals), (No, yo...         True
# 20     [(I'm, not, really), (I'm, not, sure), (I'm, n...        False
# 21     [(Except, [the, CDC), (Except, [the, study](ht...        False
# 22     [(Dr., Carson, is), (Dr., Carson, smarter), (D...         True
# 23     [(>, Am, I), (>, Am, being), (>, Am, unreasona...        False
# 24     [(Nope., You, using), (Nope., You, the), (Nope...        False
# 25     [(Lmao, values., That's), (Lmao, values., why)...        False
# 26     [(No,, as, the), (No,, as, WBC), (No,, as, con...        False
# 27     [(>No., Next., Why), (>No., Next., not?), (>No...        False
# 28     [(How, do, you), (How, do, know), (How, do, th...        False
# 29     [(I, like, your), (I, like, rebuttal), (I, lik...        False
# ...                                                  ...          ...
# 29630  [(Animal, testing, for), (Animal, testing, med...        False
# 29631  [(It, has, to), (It, has, be), (It, has, balan...        False
# 29632  [(Animal, testing, helps), (Animal, testing, t...        False
# 29633  [(Although, any, suffering), (Although, any, o...        False
# 29634  [(Animal, testing, leads), (Animal, testing, t...        False
# 29635  [(Animal, testing, is), (Animal, testing, a), ...        False
# 29636  [(Animal, testing, helps), (Animal, testing, s...        False
# 29637  [(Although, it, is), (Although, it, a), (Altho...        False
# 29638  [(Animal, testing, for), (Animal, testing, med...        False
# 29639  [(I, really, don't), (I, really, think), (I, r...        False
# 29640  [(Greek, should, leave), (Greek, should, Euroz...        False
# 29641  [(Greece, should, leave), (Greece, should, the...        False
# 29642  [(Greece, needs, to), (Greece, needs, stay), (...        False
# 29643  [(Greece, does, not), (Greece, does, deserve),...        False
# 29644  [(You, are, a), (You, are, criminal.), (You, a...         True
# 29645  [(Economic, experts, say), (Economic, experts,...        False
# 29646  [(The, EU, would), (The, EU, be), (The, EU, be...        False
# 29647  [(But, every, country), (But, every, that), (B...        False
# 29648  [(No., Greece, is), (No., Greece, one), (No., ...        False
# 29649  [(Yes,, if, the), (Yes,, if, scientifical), (Y...        False
# 29650  [(of, course, it), (of, course, all), (of, cou...         True
# 29651  [(Of, course,, with), (Of, course,, unlimited)...        False
# 29652  [(No, way,, flying), (No, way,, cars), (No, wa...        False
# 29653  [(Even, if, that), (Even, if, were), (Even, if...         True
# 29654  [(Flying, cars, are), (Flying, cars, the), (Fl...        False
# 29655  [(Flying, cars, will), (Flying, cars, become),...        False
# 29656  [(The, technical, expertise), (The, technical,...        False
# 29657  [(Yes,, companies, are), (Yes,, companies, alr...        False
# 29658  [(Too, many, slow), (Too, many, imbeciles), (T...         True
# 29659  [(Of, course, they), (Of, course, will.), (Of,...        False
#
# [29660 rows x 2 columns]
